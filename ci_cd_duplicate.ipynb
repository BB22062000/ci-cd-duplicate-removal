# %% [markdown]
# <a href="https://colab.research.google.com/github/BB22062000/ci-cd-duplicate-removal/blob/main/ci_cd_duplicate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CI/CD Pipeline with GitHub Actions for Duplicate Removal
#
# This notebook demonstrates how a duplicate removal workflow can be run and tested using Python, GitHub, and GitHub Actions.

# %%
REPO_URL = "https://github.com/BB22062000/ci-cd-duplicate-removal.git"

# %%
# !rm -rf /content/ci-cd-duplicate-removal
# !git clone https://github.com/BB22062000/ci-cd-duplicate-removal.git
# Out:
# Cloning into 'ci-cd-duplicate-removal'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 58 (delta 15), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (58/58), 29.60 KiB | 4.93 MiB/s, done.
# Resolving deltas: 100% (15/15), done.

# %%
# %cd /content/ci-cd-duplicate-removal
# !pwd
# !ls
# Out:
# /content/ci-cd-duplicate-removal
# /content/ci-cd-duplicate-removal
# data  pytest.ini  README.md  requirements.txt  src  tests

# %%
# !pip install -r requirements.txt

# %%
# !python src/remove_duplicates.py
# Out:
# Duplicate removal complete. Rows after cleaning: 918

# %%
import pandas as pd

processed_df = pd.read_csv("data/processed_dataset.csv")
processed_df
# Out:
#      age  sex  chest pain type  resting bp s  cholesterol  \
# 0     40    1                2           140          289
# 1     49    0                3           160          180
# 2     37    1                2           130          283
# 3     48    0                4           138          214
# 4     54    1                3           150          195
# ..   ...  ...              ...           ...          ...
# 913   45    1                1           110          264
# 914   68    1                4           144          193
# 915   57    1                4           130          131
# 916   57    0                2           130          236
# 917   38    1                3           138          175
#
#      fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                      0            0             172                0
# 1                      0            0             156                0
# ...

# %%
# !pytest -q
# Out:
# ...                                                                      [100%]
# 3 passed in 0.59s
